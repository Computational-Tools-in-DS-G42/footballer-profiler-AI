# %%
print("Hello")
# Out:
# Hello

# %%
import sys
print(sys.executable)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
import pandas as pd

# %%
init_df = pd.read_csv("data.csv", encoding="latin1", sep=";")

# %%
init_df.head(3)
# Out:
#    Rk             Player Nation Pos          Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF   Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39    0.0   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24    0.0   0.00  0.00   8.76    0.88
#
#    AerLost  AerWon%
# 0     1.59     22.7
# 1     1.36     59.8
# 2     0.88     50.0
#
# [3 rows x 143 columns]

# %%
list(init_df.columns)
# Out:
# ['Rk',
#  'Player',
#  'Nation',
#  'Pos',
#  'Squad',
#  'Comp',
#  'Age',
#  'Born',
#  'MP',
#  'Starts',
#  'Min',
#  '90s',
#  'Goals',
#  'Shots',
#  'SoT',
#  'SoT%',
#  'G/Sh',
#  'G/SoT',
#  'ShoDist',
#  'ShoFK',
#  'ShoPK',
#  'PKatt',
#  'PasTotCmp',
#  'PasTotAtt',
#  'PasTotCmp%',
#  'PasTotDist',
#  'PasTotPrgDist',
#  'PasShoCmp',
#  'PasShoAtt',
#  'PasShoCmp%',
#  'PasMedCmp',
#  'PasMedAtt',
#  'PasMedCmp%',
#  'PasLonCmp',
#  'PasLonAtt',
#  'PasLonCmp%',
#  'Assists',
#  'PasAss',
#  'Pas3rd',
#  'PPA',
#  'CrsPA',
#  'PasProg',
#  'PasAtt',
#  'PasLive',
#  'PasDead',
#  'PasFK',
#  'TB',
#  'PasPress',
#  'Sw',
#  'PasCrs',
#  'CK',
#  'CkIn',
#  'CkOut',
#  'CkStr',
#  'PasGround',
#  'PasLow',
#  'PasHigh',
#  'PaswLeft',
#  'PaswRight',
#  'PaswHead',
#  'TI',
#  'PaswOther',
#  'PasCmp',
#  'PasOff',
#  'PasOut',
#  'PasInt',
#  'PasBlocks',
#  'SCA',
#  'ScaPassLive',
#  'ScaPassDead',
#  'ScaDrib',
#  'ScaSh',
#  'ScaFld',
#  'ScaDef',
#  'GCA',
# ...

# %%
cols_to_keep = ["Player", "Nation", "Born", "Goals", "Pos", "Min"]
df = init_df[cols_to_keep]

# %%
list(df.columns)
df.head(30)
# Out:
#                   Player Nation  Born  Goals   Pos   Min
# 0             Max Aarons    ENG  2000   0.00    DF  2881
# 1       Yunis Abdelhamid    MAR  1987   0.06    DF  2983
# 2      Salis Abdul Samed    GHA  2000   0.04    MF  2462
# 3        Laurent Abergel    FRA  1993   0.00    MF  2956
# 4            Charles Abi    FRA  2000   0.00    FW    45
# 5         Dickson Abiama    NGA  1998   0.00    FW   726
# 6         Matthis Abline    FRA  2003   0.00    FW   103
# 7          Tammy Abraham    ENG  1997   0.50    FW  3084
# 8             Luis Abram    PER  1996   0.00    DF   560
# 9       Francesco Acerbi    ITA  1988   0.14    DF  2536
# 10           Ragnar Ache    GER  1998   0.00  MFFW   259
# 11          Mohamed Achi    FRA  2002   0.00    MF    10
# 12          Marcos Acuña    ARG  1991   0.04    DF  2260
# 13             Che Adams    SCO  1996   0.31    FW  2039
# 14           Tyler Adams    USA  1999   0.00    MF  1351
# ...

# %%
cols_to_drop = ["Rk", "Pos", "Squad", "Comp"]
df = init_df.drop(columns=cols_to_drop)
